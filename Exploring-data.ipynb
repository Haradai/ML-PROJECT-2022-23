# %%
files = ["test_audios/test_cat_1.wav"]

# %%
df_raw , df_bands, df_bands_nolin, df_pitches = feature_extract(files)
# Out:
# /var/folders/j8/64lnvrmj50q5dv_5dj_ztbz40000gn/T/ipykernel_66960/825879811.py:42: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_raw['freq'+str(i)] = np.nan
# /var/folders/j8/64lnvrmj50q5dv_5dj_ztbz40000gn/T/ipykernel_66960/825879811.py:42: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_raw['freq'+str(i)] = np.nan
# ...

# %%
df_raw
# Out:
#                            animal      freq0      freq1      freq2      freq3  \
# file
# test_audios/test_cat_1.wav      1 -12.378877 -16.185819 -20.331297 -20.381862
#
#                                 freq4      freq5      freq6      freq7  \
# file
# test_audios/test_cat_1.wav -21.114155 -24.418465 -26.269237 -26.099005
#
#                                 freq8  ...    freq241    freq242    freq243  \
# file                                   ...
# test_audios/test_cat_1.wav -24.766363  ... -56.044216 -56.044216 -56.044216
#
#                               freq244    freq245    freq246    freq247  \
# file
# test_audios/test_cat_1.wav -56.044216 -56.044216 -56.044216 -56.044216
#
#                               freq248    freq249    freq250
# file
# test_audios/test_cat_1.wav -56.044216 -56.044216 -56.044216
#
# [1 rows x 252 columns]
