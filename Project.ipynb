# %%
import pandas as pd
import numpy as np
df = pd.read_csv("dataframes/tonal_pitches.csv")
df
# Out:
#                                            file  animal  chroma_0  chroma_1  \
# 0            audio-dataset/cats_dogs/cat_74.wav       1  0.253685  0.208958
# 1    audio-dataset/cats_dogs/dog_barking_63.wav       0  0.124529  0.228619
# 2            audio-dataset/cats_dogs/cat_60.wav       1  0.148572  0.224725
# 3    audio-dataset/cats_dogs/dog_barking_77.wav       0  0.492111  0.460402
# 4            audio-dataset/cats_dogs/cat_48.wav       1  0.045169  0.016570
# ..                                          ...     ...       ...       ...
# 272          audio-dataset/cats_dogs/cat_45.wav       1  0.354733  0.368590
# 273  audio-dataset/cats_dogs/dog_barking_46.wav       0  0.387464  0.443053
# 274          audio-dataset/cats_dogs/cat_51.wav       1  0.331732  0.260106
# 275          audio-dataset/cats_dogs/cat_79.wav       1  0.118344  0.100223
# 276           audio-dataset/cats_dogs/cat_7.wav       1  0.396559  0.392054
#
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
X = df.drop(columns=['animal','file'], axis=1) 
y = df['animal']
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
model = LogisticRegression()
model.fit(X,y)
# Out:
# LogisticRegression()

# %%
from sklearn.metrics import accuracy_score, confusion_matrix
y_train_hat = model.predict(X_train)
print("Training accuracy: ",accuracy_score(y_train, y_train_hat)*100)
print('Confusion matrix:\n', confusion_matrix(y_train, y_train_hat))
# Out:
# Training accuracy:  70.04830917874396
# Confusion matrix:
#  [[ 44  43]
#  [ 19 101]]

# %%
from audio_process_functions import *

# %%
files = ["test_audios/martifentmiau_cat.wav","test_audios/martifentguau_dog_barking.wav","test_audios/polfentmiau_cat.wav","test_audios/polfentbuff_dog_barking.wav"]
df_raw , df_bands, df_bands_nolin, df_pitches = feature_extract(files)
# Out:
# /Users/josepsmachine/Documents/UNI/MACHINE_LEARNING/Project/audio_process_functions.py:49: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_raw['freq'+str(i)] = np.nan
# /Users/josepsmachine/Documents/UNI/MACHINE_LEARNING/Project/audio_process_functions.py:49: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_raw['freq'+str(i)] = np.nan
# ...

# %%
model.predict(df_pitches.loc[files].drop(columns=['animal'], axis=1))
# Out:
# array([1, 1, 1, 1])

# %%
#holacalrosa
